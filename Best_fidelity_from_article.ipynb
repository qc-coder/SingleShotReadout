# %% [markdown]
# # Work with datafile of best fidelity

# %% [markdown]
# 20180810/111144_IQ_postselection_t1=50.0.dat

# %% [markdown]
# Can not open this

# %%
datafile  = 'Data_from_paper_bestfid\\111144_IQ_postselection_t1=50.0\\111144_IQ_postselection_t1=50.0.dat'
paramfile = 'Data_from_paper_bestfid\\111144_IQ_postselection_t1=50.0\\parameters_sample.dat'

# %%
f = open(paramfile, "r")
lines = f.readlines()
f.close()

# %% [markdown]
# ## All preparations

# %%
import numpy as np
from matplotlib import pyplot as plt

#my library with classes
from lib_SSResult import SSResult

import os

# %%
# datafile2 = 'some_old_data\\092633_IQ_postselection_t1=80.0\\092633_IQ_postselection_t1=80.0.dat'
# datafile3 = 'some_old_data\\092654_IQ_postselection_t1=80.0\\092654_IQ_postselection_t1=80.0.dat'

# ssr2 = SSResult(datafile2, paramfile=paramfile)
# ssr3 = SSResult(datafile3, paramfile=paramfile)

# %%
ssr = SSResult(datafile, paramfile=paramfile)
# Out:
# data loaded
# new center of blobs:  -0.00526124162979   0.00526124162979
# data was normalised and saved
# threshold set
# x-data shifted. threshold=0
# postselection done
# histograms made
# Fidelity was calculated
# Object is created

# %%
p =ssr.plot_hists(figsize=[16,9], save=True, fname='best_Remy_180810_111144_h')
# Out:
# regime: raw_data

# %%
p =ssr.plot_hists(figsize=[16,9], regime='raw_data_and_pre', save=True, fname='best_Remy_180810_111144_h')
# Out:
# regime: raw_data_and_pre

# %%
ssr.plot_scatter_two_blob(dark=True, figsize=[16,9], save=True, fname='best_Remy_180810_111144', markersize=1, transpcy=15e-2)
# Out:
# Distance:0.01; Theta: 61
# Amp: 0.00; Phase:-108
# Amp: 0.01; Phase: 60
# Ratio amps:  6.6
# <module 'matplotlib.pyplot' from 'c:\python27\lib\site-packages\matplotlib\pyplot.pyc'>

# %%
ssr.plot_scatter_two_blob(dark=True, figsize=[16,9], save=True, fname='best_Remy_180810_111144', markersize=1, transpcy=15e-2, pre_read=True)
# Out:
# Distance:0.01; Theta: 61
# Amp: 0.00; Phase:-108
# Amp: 0.01; Phase: 60
# Ratio amps:  6.6
# <module 'matplotlib.pyplot' from 'c:\python27\lib\site-packages\matplotlib\pyplot.pyc'>

# %%
ssr.dict_fidelity
# Out:
# {'Err_e': 0.042796513236884069,
#  'Err_g': 0.014325207925379259,
#  'F': 0.9510625,
#  'F_e': 0.9640416666666667,
#  'F_g': 0.9380833333333334,
#  'F_gaus': 0.99992809507941782,
#  'F_gaus_eg': 0.99994073456885901,
#  'F_gaus_ge': 0.99991545558997674,
#  'F_post': 0.9713672344982862,
#  'F_post_e': 0.9856155266434797,
#  'F_post_g': 0.9571189423530927}
