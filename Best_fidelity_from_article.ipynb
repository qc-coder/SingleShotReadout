# %% [markdown]
# # Work with datafile of best fidelity

# %% [markdown]
# 20180810/111144_IQ_postselection_t1=50.0.dat

# %% [markdown]
# Can not open this

# %%
datafile  = 'Data_from_paper_bestfid\\111144_IQ_postselection_t1=50.0\\111144_IQ_postselection_t1=50.0.dat'
paramfile = 'Data_from_paper_bestfid\\111144_IQ_postselection_t1=50.0\\parameters_sample.dat'

# %%
f = open(paramfile, "r")
lines = f.readlines()
f.close()
lines
# Out:
# ['# Filename: 192644_parameters_Fidelity190722_192644.dat\n',
#  '# Timestamp: Mon Jul 22 19:26:44 2019  !!!carefull!!! This parameters taken just from .set file. Frequences could be shifted by ssb\n',
#  '\n',
#  '# Column 1:\n',
#  '#\tname: freq_read\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 2:\n',
#  '#\tname: power1\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 3:\n',
#  '#\tname: t_read\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 4:\n',
#  '#\tname: rudat\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 5:\n',
#  '#\tname: freq_q\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 6:\n',
#  '#\tname: power2\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 7:\n',
#  '#\tname: rudat2\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 8:\n',
#  '#\tname: tpi\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 9:\n',
#  '#\tname: nsigma\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '# Column 10:\n',
#  '#\tname: cur\n',
#  '#\ttype: value\n',
#  '#\tunits: us\n',
#  '\n',
#  '7.028000000\t0\t50e-09\t17.5\t6.337360000\t0\t0\t3.000000000000e-08\t0\t0.00056\n']

# %% [markdown]
# ## All preparations

# %%
import numpy as np
from matplotlib import pyplot as plt

#my library with classes
from lib_SSResult import SSResult

import os

# %%
ssr = SSResult(datafile, paramfile=paramfile)
# Out:
# data loaded
# new center of blobs:  -0.00174115246288   0.00174115246288
# data was normalised and saved
# threshold set
# x-data shifted. threshold=0
# postselection done
# histograms made
# Fidelity was calculated
# Object is created

# %%
ssr.timestamp
# Out:
# 'Fri Aug 10 11:11:44 2018'

# %%
p =ssr.plot_hists(figsize=[16,9], save=True, fname='best_Remy_180810_111144_h')
# Out:
# regime: raw_data

# %%
ssr.plot_scatter_two_blob(dark=True, figsize=[16,9], save=True, fname='best_Remy_180810_111144')
# Out:
# Distance:0.00; Theta:-14
# Amp: 0.00; Phase:-5.4
# Amp: 0.01; Phase:-9.4
# Ratio amps:  1.8
# <module 'matplotlib.pyplot' from 'c:\python27\lib\site-packages\matplotlib\pyplot.pyc'>

# %%
ssr.dict_fidelity
# Out:
# {'Err_e': 0.19278900992120154,
#  'Err_g': -0.006085501329024065,
#  'F': 0.8418541666666667,
#  'F_e': 0.921375,
#  'F_g': 0.7623333333333333,
#  'F_gaus': 0.94102502227632245,
#  'F_gaus_eg': 0.91519340342095501,
#  'F_gaus_ge': 0.9668566411316899,
#  'F_post': 0.8476732679802337,
#  'F_post_e': 0.9212789047499791,
#  'F_post_g': 0.7740676312104884}
