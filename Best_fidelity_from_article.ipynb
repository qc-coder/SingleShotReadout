# %% [markdown]
# # Work with datafile of best fidelity

# %% [markdown]
# 20180810/111144_IQ_postselection_t1=50.0.dat

# %% [markdown]
# Can not open this

# %%
datafile  = 'Data_from_paper_bestfid\\111144_IQ_postselection_t1=50.0\\111144_IQ_postselection_t1=50.0.dat'
paramfile = 'Data_from_paper_bestfid\\111144_IQ_postselection_t1=50.0\\parameters_sample.dat'

# %%
f = open(paramfile, "r")
lines = f.readlines()
f.close()

# %%
# f = open(datafile, "r")
# lines = f.readlines()
# f.close()

# %% [markdown]
# ## All preparations

# %%
import numpy as np
from matplotlib import pyplot as plt

#my library with classes
from lib_SSResult import SSResult

import os

# %%
ssr = SSResult(datafile, paramfile=paramfile)
# Out:
# data loaded
# new center of blobs:  -0.00526124162979   0.00526124162979
# data was normalised and saved
# threshold set
# x-data shifted. threshold=0
# postselection done
# histograms made
# Fidelity was calculated
# Object is created

# %%
p =ssr.plot_hists(figsize=[16,9], save=True, fname='best_Remy_180810_111144_h')
# Out:
# regime: raw_data
# c:\python27\lib\site-packages\matplotlib\figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
ssr.plot_scatter_two_blob(dark=True, figsize=[16,9], save=True, fname='best_Remy_180810_111144')
# Out:
# Distance:0.01; Theta:-118
# Amp: 0.01; Phase: 60
# Amp: 0.00; Phase:-108
# Ratio amps:  0.2
# <module 'matplotlib.pyplot' from 'c:\python27\lib\site-packages\matplotlib\pyplot.pyc'>

# %%
ssr.dict_fidelity
# Out:
# {'Err_e': 0.25480027550008272,
#  'Err_g': 0.30718090200990572,
#  'F': 0.9510625,
#  'F_e': 0.9380833333333334,
#  'F_g': 0.9640416666666667,
#  'F_gaus': 0.99867129411058297,
#  'F_gaus_eg': 0.99992627896580899,
#  'F_gaus_ge': 0.99741630925535696,
#  'F_post': 0.7176807053555887,
#  'F_post_e': 0.6927453769559033,
#  'F_post_g': 0.7426160337552743}

# %%
ssr.re_g
# Out:
# array([ 0.0017236 ,  0.00459151,  0.00073623, ...,  0.002949  ,
#        -0.00058281, -0.00035628])

# %%
ssr.re_e
# Out:
# array([-0.00050571, -0.00089521, -0.00091415, ..., -0.00076267,
#         0.00106803, -0.00156203])

# %%
ssr.im_g
# Out:
# array([ 0.00152409,  0.00733471,  0.00096886, ...,  0.00529945,
#        -0.00108757, -0.00242252])

# %%
ssr.im_e
# Out:
# array([-0.00326919, -0.00218631, -0.00312009, ..., -0.00379313,
#         0.00139223, -0.00253989])

# %%
ssr.re_g_pre
# Out:
# array([-0.00220709, -0.00205565, -0.00036043, ..., -0.00083659,
#         0.00457605, -0.00036358])

# %%
ssr.re_e_pre
# Out:
# array([-0.00080727, -0.0020879 , -0.0006798 , ..., -0.00154594,
#        -0.00043112, -0.00106676])

# %%
ssr.im_g_pre
# Out:
# array([-0.00040154, -0.00252699, -0.00041243, ...,  0.00089472,
#         0.00778113, -0.0017975 ])

# %%
ssr.im_e_pre
# Out:
# array([-0.00300839, -0.00386957, -0.00405968, ..., -0.00207179,
#        -0.00392084, -0.00154291])
